# %%
import nota_bene
nota_bene.register_nb_skip()

# %% [markdown]
# ---
# ## `plain-data` · Cell 2 · No tests
#
# No tests yet. Edit the source cell below, write a test with `%%nb_skip` / `# test: <name>`, then run `nota-bene edit --continue <notebook>`.

# %%
data = [1, 2, 3, 4, 5]

# %% [markdown]
# ---
# ## `compute-total` · Cell 3 · Needs review
#
# Tests exist but have never been validated against the current source (no SHA recorded yet). Review the test cell below, then run `nota-bene edit --continue <notebook>` to lock in the current state.
#
# **Why:** No staleness data (shas missing)

# %%
# fixture: setup_data
# description: Override data so the sum is a known value
# priority: 0
data = [10, 20, 30]

# %%
total = sum(data)

# %%
# %%nb_skip
# # test: check_total
# assert total == 60, f"expected 60, got {total}"

# %% [markdown]
# ---
# ## `reviewed-pass` · Cell 4 · Needs review
#
# Tests exist but have never been validated against the current source (no SHA recorded yet). Review the test cell below, then run `nota-bene edit --continue <notebook>` to lock in the current state.
#
# **Why:** No staleness data (shas missing)

# %%
# fixture: 
# description: 
# priority: 0

# %%
pass

# %%
# %%nb_skip
# # test: <unnamed>
# Out:
# Skipped: # test: <unnamed>

# %% [markdown]
# ---
# ## `b451fcb4-6e4d-481c-962f-d9bd647e9419` · Cell 5 · No tests
#
# No tests yet. Edit the source cell below, write a test with `%%nb_skip` / `# test: <name>`, then run `nota-bene edit --continue <notebook>`.
