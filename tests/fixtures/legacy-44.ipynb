# %% [markdown]
# # Legacy notebook (nbformat 4.4)
#
# This fixture has no `id` fields on cells.  Used to test `ipso upgrade`.

# %%
x = 1 + 1
x

# %%
y = x * 2
y

# %%
# This cell has no _cell_guid — its ID should be a generated UUID.
z = x + y
